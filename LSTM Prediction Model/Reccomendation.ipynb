# %% [markdown]
# # Stock Price Forecasting
# Goals:
# - Use historical data to create a machine learning algorithm to predict future stock price
# - Train and validate model to improve precision and accuracy

# %% [markdown]
# ## Background
# ### RNN's (Recurrent Nueral Netowrks)
# - designed to function like the frontal lobe of the brain
# - this is responsible for short term memory, and can recall near past to make decisions for the immediate future
#
# ### LSTM Models
# - We will be working with an LSTM model by KERAS a tensorflow application

# %% [markdown]
# ## Part 1 ETL Layer
# 1) Extract: Query data from Yahoo Finance
# - If you would like to do this we covered this in the last meeting -- however for everyones convienence I have inlucded a CSV of Microsoft's historical stock data
# - This data is from the Yahoo Finance API

# %% [markdown]
# ### Interpreting and manipulating data
# - Stocks can be classified into three groups
#     1. Open
#     2. High
#     3. Low
#     4. Close
# - We will ignore the `Adj Close` and `Volume` columns for this project

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
training_set = pd.read_csv('MSFT-2.csv')
# transform the data to a numpy array
training_set = training_set.iloc[:, 1:2].values
training_set[0:5]
# Out:
# array([[235.059998],
#        [241.300003],
#        [239.570007],
#        [242.660004],
#        [242.229996]])

# %% [markdown]
# ### Feature Scaling
# 1. Normalization of Inputs: Feature scaling in LSTMs helps to normalize the input data such that all the features are on a similar scale. This is important in LSTMs because the model uses activation functions like sigmoid or tanh that operate best on inputs in the range of -1 to 1.
# <p align=center>
# *tanh function*
# </p>
#
#
# $$
# \begin{align}
#
#     f(x) = tanh(x) = \frac{2}{1+e^{-2x}}-1 \\
#
# \end{align}
# $$
#
# <p align=center>
# *sigmoid function*
# </p>
#
#
# $$
# \begin{align}
#     \phi(z) = \frac{1}{1+e^{-z}} \\
# \end{align}
# $$
# 2. Improved Training Speed: Normalizing inputs through feature scaling can speed up the training process of an LSTM. It helps to avoid slow convergence and the vanishing gradient problem, making it easier for the model to learn from the data.
# 3. Better Generalization: Feature scaling can help improve the generalization ability of an LSTM by making the model less sensitive to the scale of the input features. This can lead to better performance on unseen data.
# 4. Consistent Interpretation: Normalizing inputs through feature scaling can help maintain consistent interpretations of feature importance across different features, allowing for better interpretation of the model's predictions.

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(training_set)
training_set_scaled[0:5]
# Out:
# array([[0.0705802 ],
#        [0.12351543],
#        [0.10883952],
#        [0.1350526 ],
#        [0.13140475]])

# %% [markdown]
# ### Splitting into X and Y training
# - cannot have x go to the end and cannot have y start at the first index
# - cannot include the 0th day prediction

# %%
# find the number of rows to train the model on
training_set_scaled.shape
X_train = training_set_scaled[0:252]
Y_train = training_set_scaled[1:253]
print(f'X train is \n {X_train[0:5]}')
print(f'Y train is \n {Y_train[0:5]}')
# Out:
# X train is
#  [[0.0705802 ]
#  [0.12351543]
#  [0.10883952]
#  [0.1350526 ]
#  [0.13140475]]
# Y train is
#  [[0.12351543]
#  [0.10883952]
#  [0.1350526 ]
#  [0.13140475]
#  [0.13920928]]

# %%
# Reshaping by adding a time dimension to the data
X_train = np.reshape(X_train, (252, 1, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
regressor = Sequential()
regressor.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, Y_train, batch_size = 32, epochs = 200)
# Out:
# 2023-01-31 18:24:37.055160: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 18:24:45.011116: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 8/8 [==============================] - 2s 3ms/step - loss: 0.1286
# Epoch 2/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1276
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1266
# Epoch 4/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1257
# Epoch 5/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1247
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1238
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1228
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1218
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1209
# Epoch 10/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1200
# Epoch 11/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1190
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1181
# Epoch 13/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1172
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1163
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1154
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1145
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1136
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1127
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1119
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1110
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1101
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1085
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1068
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1060
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1052
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1044
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1037
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1029
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1021
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1014
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1006
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0999
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0992
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0984
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0977
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0970
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0957
# Epoch 41/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0950
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0943
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0937
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0931
# Epoch 45/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0924
# Epoch 46/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0918
# Epoch 47/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0912
# Epoch 48/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0906
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0900
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0894
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0889
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0883
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 55/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0867
# Epoch 56/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0862
# Epoch 57/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0852
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0847
# Epoch 60/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0842
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0837
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0828
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0819
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0810
# Epoch 68/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0802
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0798
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0794
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0790
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0779
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0775
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0772
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0768
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0761
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0755
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0749
# Epoch 85/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0746
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0743
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0740
# Epoch 88/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0737
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0734
# Epoch 90/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0732
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0729
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0726
# Epoch 93/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0724
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0721
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0719
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 97/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0712
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0709
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 101/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0705
# Epoch 102/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0703
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 106/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0694
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0692
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0690
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0688
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0686
# Epoch 111/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0684
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0683
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0679
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0677
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0676
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0674
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0672
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0669
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0667
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0664
# Epoch 124/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0662
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0661
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0658
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0656
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0655
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0653
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0652
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0650
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0649
# Epoch 134/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0648
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0646
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0645
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0642
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0641
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 141/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0638
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0635
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0634
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0633
# Epoch 146/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0632
# Epoch 147/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0630
# Epoch 148/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0629
# Epoch 149/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0627
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0625
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0624
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0623
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0622
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0621
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0619
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0618
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0617
# Epoch 159/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0616
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0615
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0613
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0612
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0611
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0610
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0609
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0608
# Epoch 167/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0607
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0605
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0604
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0603
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0601
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0598
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0596
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0594
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0593
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0592
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0591
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0590
# Epoch 183/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0589
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0584
# Epoch 188/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0583
# Epoch 189/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0582
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0581
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0580
# Epoch 192/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0579
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0577
# Epoch 195/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0576
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 197/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0573
# Epoch 198/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 199/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0571
# Epoch 200/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0570

# %% [markdown]
# ### Your Task:
# 1. Collect data on Microsofts Historical Stock data (need a testing dataset)
# 2. Transform the data in the same way as the training data

# %%
# Getting the real stock price of MSFT
test_set = pd.read_csv(None) #TODO: replace None with the path to the test set
real_stock_price = test_set.iloc[:, 1:2].values #transforming the data to a numpy array
inputs = sc.transform(real_stock_price) #scaling the data
inputs = np.reshape(inputs, (20, 1, 1)) #reshaping the data

# %%
predicted_stock_price = regressor.predict(inputs) #predicting the stock price
predicted_stock_price = sc.inverse_transform(predicted_stock_price) #inverse transforming the data

# %% [markdown]
# ### Plotting Your Findings
# 1. Use matplotlib (or your plotting library of choice)
#     - [Matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)
#     - [Plotly](https://plotly.com/python/line-charts/)
# 2. Compare the real stock prices and the predicted price

# %%
# Visualising the results

# %% [markdown]
# ### Question:
# How can you improve this process to make this into a better project that uses machine learning to predict stock prices, or the price of anything else?
